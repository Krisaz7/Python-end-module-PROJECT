# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('dataset.csv')
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    object
#  6   Weight    458 non-null    int64
#  7   College   374 non-null    object
#  8   Salary    447 non-null    float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 32.3+ KB

# %%
df.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %%
df['Height']=np.random.randint(150,180+1,len(df))
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     156     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     165     235
# 2     John Holland  Boston Celtics      30       SG   27     166     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     172     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     169     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     175     203
# 454      Raul Neto       Utah Jazz      25       PG   24     171     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     155     256
# 456    Jeff Withey       Utah Jazz      24        C   26     152     231
# 457       Priyanka       Utah Jazz      34        C   25     169     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df.fillna(value={'Salary': 0,'College':'Unspecified'})
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     156     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     165     235
# 2     John Holland  Boston Celtics      30       SG   27     166     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     172     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     169     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     175     203
# 454      Raul Neto       Utah Jazz      25       PG   24     171     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     155     256
# 456    Jeff Withey       Utah Jazz      24        C   26     152     231
# 457       Priyanka       Utah Jazz      34        C   25     169     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
 #How many are there in each Team 
team_count = df['Team'].value_counts()
team_count
# Out:
# Team
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# Utah Jazz                 16
# New York Knicks           16
# Milwaukee Bucks           16
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Boston Celtics            15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Dallas Mavericks          15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: count, dtype: int64

# %%
total_count=sum(team_count)
total_count
# Out:
# 458

# %%
#percentage=((team_count/total_count)*100)
(((df["Team"].value_counts()/total_count)*100).round(2))
# Out:
# Team
# New Orleans Pelicans      4.15
# Memphis Grizzlies         3.93
# Utah Jazz                 3.49
# New York Knicks           3.49
# Milwaukee Bucks           3.49
# Brooklyn Nets             3.28
# Portland Trail Blazers    3.28
# Oklahoma City Thunder     3.28
# Denver Nuggets            3.28
# Washington Wizards        3.28
# Miami Heat                3.28
# Charlotte Hornets         3.28
# Atlanta Hawks             3.28
# San Antonio Spurs         3.28
# Houston Rockets           3.28
# Boston Celtics            3.28
# Indiana Pacers            3.28
# Detroit Pistons           3.28
# Cleveland Cavaliers       3.28
# Chicago Bulls             3.28
# Sacramento Kings          3.28
# Phoenix Suns              3.28
# Los Angeles Lakers        3.28
# Los Angeles Clippers      3.28
# Golden State Warriors     3.28
# Toronto Raptors           3.28
# Philadelphia 76ers        3.28
# Dallas Mavericks          3.28
# Orlando Magic             3.06
# Minnesota Timberwolves    3.06
# ...

# %%
#2.Segregate the employees w.r.t different positions.
emp=df.groupby('Position')

for i,group_data in emp:
    print("Employees in Position:",i)
    print(group_data)
# Out:
# Employees in Position: C
#                 Name                    Team  Number Position  Age  Height  \
# 7       Kelly Olynyk          Boston Celtics      41        C   25     169
# 10   Jared Sullinger          Boston Celtics       7        C   24     175
# 14      Tyler Zeller          Boston Celtics      44        C   26     171
# 23       Brook Lopez           Brooklyn Nets      11        C   28     162
# 27        Henry Sims           Brooklyn Nets      14        C   26     174
# ..               ...                     ...     ...      ...  ...     ...
# 439    Mason Plumlee  Portland Trail Blazers      24        C   26     165
# 447      Rudy Gobert               Utah Jazz      27        C   23     152
# 455     Tibor Pleiss               Utah Jazz      21        C   26     155
# 456      Jeff Withey               Utah Jazz      24        C   26     152
# 457         Priyanka               Utah Jazz      34        C   25     169
#
# ...

# %%
#Find from which age group most of the employees belong to.

# Create the histogram plot
plt.hist(df['Age'])

# Customize the plot
plt.xlabel('Age')
plt.ylabel('No of times')
plt.title('HISTOGRAM')

# Display the plot
plt.show()

# %%
max_spend=df.groupby(['Team', 'Position'])['Salary'].sum()
max_salary=max_spend.idxmax()
max_salary
print("The team and position, whose spending in terms of salary is high is ",max_salary[0],',',max_salary[1])
# Out:
# The team and position, whose spending in terms of salary is high is  Los Angeles Lakers , SF

# %%
data=df.drop(['Name','Team', 'Position','College', 'Height'], axis='columns')
corr = data.corr()
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.title("Correlation between Age and Salary ")
plt.show()
